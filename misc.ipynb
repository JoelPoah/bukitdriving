# %%
import json
def load_users(json_file):
    with open(json_file, "r") as f:
        return json.load(f)
    
def run_search_for_users(json_file):
    users = load_users(json_file)
    
    for user_id, user_data in users.items():
        username = user_data["USERNAME"]
        password = user_data["PASSWORD"]
        dates = user_data["DATES"]
        
        
run_search_for_users("user_data.json")
# Out:
# @nhq1i

# %%
from datetime import datetime,timedelta

data = {"code":None,"success":True,"message":None,"routeToURL":None,"resultObject":None,"data":{"releasedSlotMonthList":[{"slotMonthEn":"Jul'24","slotMonthYm":"202407"}],
                                                                                                
                                                                                                
                                                                                                "releasedSlotListGroupByDay":{"2024-07-27 00:00:00":[{"slotId":2221282,"slotIdEnc":
                                                                                                    "XHEtW2ICa7GFDRVNuD8K7SUhCNPs3iyv2HVs37Cdtew=","slotRefName":"SESSION 3",
                                                                                                    "slotRefDate":"2024-09-02 00:00:00",
"startTime":"19:30","endTime":"13:10","trainingFee":72.0000,"gst":9,"gstFee":6.48,"baseFee":78.4800,"totalFee":78.4800,"warmUpWithGstFee":None,"rentalWithGstFee":None,"commFee":None,"commWithGstFee":None,"fixedInstructorSurcharge":0,"venueId":1,"slotAvlComputed":True,"bookingProgress":"Available","bookingProgressEnc":"4fYSpRb58xvZF//mzRgJnN905VEpQAuSgGWhalHlXh4=","computedSlotAvl":1,"success":False,"message":None,"startDateTime":None,"c3PsrSlotId":2221282,"c3PsrFixGrpNo":"G6066","c3PsrTrainingDate":"2024-07-26T16:00:00.000+00:00","c3PsrSessionNo":3,"c3PsrSlotAssign":5,"c3PsrSlotAvl":0,"c3PsrTrysell":1,"c3PsrCutOffDate":"2024-07-26T16:00:00.000+00:00","c3PsrStartTime":None,"c3PsrEndTime":None,"c3PsrPriceType":"N","c3PsrSlotRRAss":0,"c3PsrSlotRRAvl":0,"c3PsrTakeBackAss":4,"c3PsrTakeBackRR":1,"c3PsrSlotIndicator":"Class 3","c3PsrUserId":None,"c3PsrTimeStamp":None,"c3PsrVenueId":None,"venueName":"BBDC","c3TrainingFeeDtlDTO":{"c3tId":119,"c3tType":"Class 3","c3tPriceType":"NORMAL","c3tDayTrainingFee":64.0000,"c3tDayGst":9,"c3tNightTrainingFee":72.0000,"c3tNightGst":9,"c3tDateOpt":"Booking Date","c3tEffectiveDate":"2023-12-31T16:00:00.000+00:00","c3tUserId":"1152","c3tTimeStamp":"2023-12-21T07:28:04.800+00:00"},"fixedInstructorFeeDtlDTO":None,"slotSurcharge":0.0000,"venueSurcharge":0.0000,"pickupPointSurcharge":0.0000,"c3SlotType":None,"fgCarmodel":"C","fgTransType":"M","otherGroupNo":"G6066","otherCarModel":None,"userFixGrpNo":"G6066","userCarModel":"C","userPickupPoint":None}]},"accountBal":345.6400,"couNegActive":"0"}}
def check(slots):
    print('executing check()')

    # Define the desired days for each month
    wanted_days = {
        8: {"weekday":[9,12,13,14,15,16,19,20,21,22,23,26,27,28,29,30,31],"weekend":[10,11,17,18,24,25]},
        9:{"weekday":[2,3,4,5,6,9,10,11,12,13,16,17,18,19,20,23,24,25,26,27,30],"weekend":[1,7,8,14,15,21,22,28,29]},
        10:{"weekday":[1,2,3,4,7,8,9,10,11,14,15,16,17,18,21,22,23,24,25,28,29,30,31],"weekend":[5,6,12,13,19,20,26,27]}# August (add more days if needed)
    }

    try:
        date_now = datetime.now()
        slot_data = slots['data']['releasedSlotListGroupByDay']
        
        for key, value in slot_data.items():
            for index, slot_row in enumerate(value):
                date = slot_row['slotRefDate']
                # Convert date to a proper date format
                date = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
                start_time = slot_row['startTime']
                start_time = datetime.strptime(start_time, '%H:%M')
                # Filter only the wanted days for the specified month
                if date.month in wanted_days and date.day == 8 and start_time.hour >=12:
                    return slot_row
                if date.month in wanted_days and date.day in wanted_days[date.month]['weekday'] and start_time.hour >=19:
                    return slot_row
                elif date.month in wanted_days and date.day in wanted_days[date.month]['weekend'] and start_time.hour <=12:
                    return slot_row
          
    except Exception as e:
        print('error in check()')
        print(e)

check(data)
# Out:
# executing check()
# {'slotId': 2221282,
#  'slotIdEnc': 'XHEtW2ICa7GFDRVNuD8K7SUhCNPs3iyv2HVs37Cdtew=',
#  'slotRefName': 'SESSION 3',
#  'slotRefDate': '2024-09-02 00:00:00',
#  'startTime': '19:30',
#  'endTime': '13:10',
#  'trainingFee': 72.0,
#  'gst': 9,
#  'gstFee': 6.48,
#  'baseFee': 78.48,
#  'totalFee': 78.48,
#  'warmUpWithGstFee': None,
#  'rentalWithGstFee': None,
#  'commFee': None,
#  'commWithGstFee': None,
#  'fixedInstructorSurcharge': 0,
#  'venueId': 1,
#  'slotAvlComputed': True,
#  'bookingProgress': 'Available',
#  'bookingProgressEnc': '4fYSpRb58xvZF//mzRgJnN905VEpQAuSgGWhalHlXh4=',
#  'computedSlotAvl': 1,
#  'success': False,
#  'message': None,
#  'startDateTime': None,
#  'c3PsrSlotId': 2221282,
#  'c3PsrFixGrpNo': 'G6066',
#  'c3PsrTrainingDate': '2024-07-26T16:00:00.000+00:00',
#  'c3PsrSessionNo': 3,
#  'c3PsrSlotAssign': 5,
#  'c3PsrSlotAvl': 0,
#  'c3PsrTrysell': 1,
#  'c3PsrCutOffDate': '2024-07-26T16:00:00.000+00:00',
#  'c3PsrStartTime': None,
# ...

# %%
import json

USERS = json.loads(open('user_data.json').read())

print(USERS)
# Out:
# {'587628950': {'USERNAME': '105F26022004', 'PASSWORD': '020975', 'DATES': [1, 2, 3, 4, 5]}, '1234': {'username': 'test'}}

# %%
# write to file

USERS['1234'] = {
    'username': 'test',
}
with open('user_data.json', 'w') as f:
    json.dump(USERS, f, indent=4)

# %%
import requests
import json
class_booked = '''{
  "code": "null",
  "success": "true",
  "message": "null",
  "routeToURL": "null",
  "resultObject": "null",
  "data": {
    "releasedSlotMonthList": [
      {
        "slotMonthEn": "Jul'24",
        "slotMonthYm": "202407"
      },
      {
        "slotMonthEn": "Aug'24",
        "slotMonthYm": "202408"
      },
      {
        "slotMonthEn": "Sep'24",
        "slotMonthYm": "202409"
      }
    ],
    "releasedSlotListGroupByDay": {
      "2024-07-16 00:00:00": [
        {
          "slotId": 2222922,
          "slotIdEnc": "XBZKcGs81vZ0ZI2QORtCHK82M5mBkYi2ZhQgg2V0Pus=",
          "slotRefName": "SESSION 4",
          "slotRefDate": "2024-07-16 00:00:00",
          "startTime": "13:20",
          "endTime": "15:00",
          "trainingFee": 64.0000,
          "gst": 9,
          "gstFee": 5.76,
          "baseFee": 69.7600,
          "totalFee": 69.7600,
          "warmUpWithGstFee": "null",
          "rentalWithGstFee": "null",
          "commWithGstFee": "null",
          "fixedInstructorSurcharge": 0,
          "venueId": 1,
          "slotAvlComputed": "true",
          "bookingProgress": "Available",
          "bookingProgressEnc": "EXugjlT0wzV0+TD2mjoQ/Jith3gKecAiZmKlKk+KZUM=",
          "computedSlotAvl": 1,
          "success": "false",
          "message": "null",
          "startDateTime": "null",
          "c3PsrSlotId": 2222922,
          "c3PsrFixGrpNo": "G6067",
          "c3PsrTrainingDate": "2024-07-15T16:00:00.000+00:00",
          "c3PsrSessionNo": 4,
          "c3PsrSlotAssign": 5,
          "c3PsrSlotAvl": 1,
          "c3PsrTrysell": 0,
          "c3PsrCutOffDate": "2024-07-15T16:00:00.000+00:00",
          "c3PsrStartTime": "null",
          "c3PsrEndTime": "null",
          "c3PsrPriceType": "D",
          "c3PsrSlotRRAss": 0,
          "c3PsrSlotRRAvl": 0,
          "c3PsrTakeBackAss": 0,
          "c3PsrTakeBackRR": 0,
          "c3PsrSlotIndicator": "Class 3",
          "c3PsrUserId": "null",
          "c3PsrTimeStamp": "null",
          "c3PsrVenueId": "null",
          "venueName": "BBDC",
          "c3TrainingFeeDtlDTO": {
            "c3tId": 119,
            "c3tType": "Class 3",
            "c3tPriceType": "NORMAL",
            "c3tDayTrainingFee": 64.0000,
            "c3tDayGst": 9,
            "c3tNightTrainingFee": 72.0000,
            "c3tNightGst": 9,
            "c3tDateOpt": "Booking Date",
            "c3tEffectiveDate": "2023-12-31T16:00:00.000+00:00",
            "c3tUserId": "1152",
            "c3tTimeStamp": "2023-12-21T07:28:04.800+00:00"
          },
          "fixedInstructorFeeDtlDTO": "null",
          "slotSurcharge": 0.0000,
          "venueSurcharge": 0.0000,
          "pickupPointSurcharge": 0.0000,
          "c3SlotType": "null",
          "fgCarmodel": "null",
          "fgTransType": "null",
          "otherGroupNo": "null",
          "otherCarModel": "null",
          "userFixGrpNo": "G6067",
          "userCarModel": "C",
          "userPickupPoint": "null"
        }
      ],
      "2024-07-18 00:00:00": [
        {
          "slotId": 2222790,
          "slotIdEnc": "8/MLxWk7671l7vkzN1TDCxngyL6VTvbkqK1LiHn+A5c=",
          "slotRefName": "SESSION 2",
          "slotRefDate": "2024-07-18 00:00:00",
          "startTime": "09:20",
          "endTime": "11:00",
          "trainingFee": 72.0000,
          "gst": 9,
          "gstFee": 6.48,
          "baseFee": 78.4800,
          "totalFee": 78.4800,
          "warmUpWithGstFee": "null",
          "rentalWithGstFee": "null",
          "commWithGstFee": "null",
          "fixedInstructorSurcharge": 0,
          "venueId": 1,
          "slotAvlComputed": "true",
          "bookingProgress": "Available",
          "bookingProgressEnc": "UMx6vxroAAa/eUyTmtotyZPnkJ9ZKIDDHrpCxnaLBoU=",
          "computedSlotAvl": 1,
          "success": "false",
          "message": "null",
          "startDateTime": "null",
          "c3PsrSlotId": 2222790,
          "c3PsrFixGrpNo": "G6067",
          "c3PsrTrainingDate": "2024-07-17T16:00:00.000+00:00",
          "c3PsrSessionNo": 2,
          "c3PsrSlotAssign": 6,
          "c3PsrSlotAvl": 1,
          "c3PsrTrysell": 0,
          "c3PsrCutOffDate": "2024-07-17T16:00:00.000+00:00",
          "c3PsrStartTime": "null",
          "c3PsrEndTime": "null",
          "c3PsrPriceType": "D",
          "c3PsrSlotRRAss": 0,
          "c3PsrSlotRRAvl": 0,
          "c3PsrTakeBackAss": 0,
          "c3PsrTakeBackRR": 0,
          "c3PsrSlotIndicator": "Class 3",
          "c3PsrUserId": "null",
          "c3PsrTimeStamp": "null",
          "c3PsrVenueId": "null",
          "venueName": "BBDC",
          "c3TrainingFeeDtlDTO": {
            "c3tId": 119,
            "c3tType": "Class 3",
            "c3tPriceType": "NORMAL",
            "c3tDayTrainingFee": 64.0000,
            "c3tDayGst": 9,
            "c3tNightTrainingFee": 72.0000,
            "c3tNightGst": 9,
            "c3tDateOpt": "Booking Date",
            "c3tEffectiveDate": "2023-12-31T16:00:00.000+00:00",
            "c3tUserId": "1152",
            "c3tTimeStamp": "2023-12-21T07:28:04.800+00:00"
          },
          "fixedInstructorFeeDtlDTO": "null",
          "slotSurcharge": 0.0000,
          "venueSurcharge": 0.0000,
          "pickupPointSurcharge": 0.0000,
          "c3SlotType": "null",
          "fgCarmodel": "null",
          "fgTransType": "null",
          "otherGroupNo": "null",
          "otherCarModel": "null",
          "userFixGrpNo": "G6067",
          "userCarModel": "C",
          "userPickupPoint": "null"
        }
      ]
    }
  },
  "errorCode": "null",
  "isLogin": "null"
}'''



# convert string to json
class_booked = json.loads(class_booked)
print(type(class_booked))

print(class_booked['data']['releasedSlotListGroupByDay'])

# requests.post(f"https://api.callmebot.com/text.php?user=@JoelPP&text={class_booked}")
# Out:
# <class 'dict'>
# ...

# %%
from datetime import datetime
data = {'2024-07-16 00:00:00': [{'slotId': 2222922, 'slotIdEnc': 'XBZKcGs81vZ0ZI2QORtCHB8uSaxfa1clf0FmZKYw3OY=', 'slotRefName': 'SESSION 4', 'slotRefDate': '2024-06-16 00:00:00', 'startTime': '13:20', 'endTime': '15:00', 'trainingFee': 64.0, 'gst': 9, 'gstFee': 5.76, 'baseFee': 69.76, 'totalFee': 69.76, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'EXugjlT0wzV0+TD2mjoQ/Jith3gKecAiZmKlKk+KZUM=', 'computedSlotAvl': 1, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2222922, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-15T16:00:00.000+00:00', 'c3PsrSessionNo': 4, 'c3PsrSlotAssign': 5, 'c3PsrSlotAvl': 1, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-15T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'D', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 0, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 119, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 64.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 72.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Booking Date', 'c3tEffectiveDate': '2023-12-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-21T07:28:04.800+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}], '2024-07-18 00:00:00': [{'slotId': 2222790, 'slotIdEnc': '8/MLxWk7671l7vkzN1TDC6vJ3U7kEFwKR8SHlbdChW8=', 'slotRefName': 'SESSION 2', 'slotRefDate': '2024-07-18 00:00:00', 'startTime': '09:20', 'endTime': '11:00', 'trainingFee': 72.0, 'gst': 9, 'gstFee': 6.48, 'baseFee': 78.48, 'totalFee': 78.48, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'UMx6vxroAAa/eUyTmtotyZPnkJ9ZKIDDHrpCxnaLBoU=', 'computedSlotAvl': 1, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2222790, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-17T16:00:00.000+00:00', 'c3PsrSessionNo': 2, 'c3PsrSlotAssign': 6, 'c3PsrSlotAvl': 1, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-17T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'N', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 0, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 119, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 64.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 72.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Booking Date', 'c3tEffectiveDate': '2023-12-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-21T07:28:04.800+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}, {'slotId': 2222801, 'slotIdEnc': 'CUH2AS/Oow/HDvfWF+/wvFppqXMjI1XDC6PKk9pCFfw=', 'slotRefName': 'SESSION 3', 'slotRefDate': '2024-07-18 00:00:00', 'startTime': '11:30', 'endTime': '13:10', 'trainingFee': 72.0, 'gst': 9, 'gstFee': 6.48, 'baseFee': 78.48, 'totalFee': 78.48, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'FMMfFEgD0lUf6Dv0QDhRDDeGiR8dwQl9AjmweSPYHKU=', 'computedSlotAvl': 1, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2222801, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-17T16:00:00.000+00:00', 'c3PsrSessionNo': 3, 'c3PsrSlotAssign': 6, 'c3PsrSlotAvl': 1, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-17T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'N', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 0, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 119, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 64.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 72.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Booking Date', 'c3tEffectiveDate': '2023-12-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-21T07:28:04.800+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}], '2024-08-01 00:00:00': [{'slotId': 2228809, 'slotIdEnc': 'VuSzhAQGG1eD6pIePdbCge/4Y/NbX/NxCp8sTQE8v2E=', 'slotRefName': 'SESSION 1', 'slotRefDate': '2024-08-01 00:00:00', 'startTime': '07:30', 'endTime': '09:10', 'trainingFee': 66.0, 'gst': 9, 'gstFee': 5.94, 'baseFee': 71.94, 'totalFee': 71.94, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'qGhnPjoXU4Fpfdd1uDeJmLRWQRxK/GHp3zeJQAV7Dfg=', 'computedSlotAvl': 1, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2228809, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrSessionNo': 1, 'c3PsrSlotAssign': 3, 'c3PsrSlotAvl': 1, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'D', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 2, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 123, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 66.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 74.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Training Date', 'c3tEffectiveDate': '2024-07-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-31T15:49:58.350+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}, {'slotId': 2228820, 'slotIdEnc': '/frQOyiBfFulbjBkl5Ajx6Cx3zu4immomScfYCDpucw=', 'slotRefName': 'SESSION 2', 'slotRefDate': '2024-08-01 00:00:00', 'startTime': '09:20', 'endTime': '11:00', 'trainingFee': 74.0, 'gst': 9, 'gstFee': 6.66, 'baseFee': 80.66, 'totalFee': 80.66, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'dWWjoR7O7a9ua4XpDakKEBJ2EM9pNPEA0zATJUSZDpo=', 'computedSlotAvl': 2, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2228820, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrSessionNo': 2, 'c3PsrSlotAssign': 3, 'c3PsrSlotAvl': 2, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'N', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 2, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 123, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 66.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 74.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Training Date', 'c3tEffectiveDate': '2024-07-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-31T15:49:58.350+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}, {'slotId': 2229271, 'slotIdEnc': 'pTJldNXIE4T40XoEnb66ZXyjTbygR5FDHBPAUBcT2UY=', 'slotRefName': 'SESSION 3', 'slotRefDate': '2024-08-01 00:00:00', 'startTime': '11:30', 'endTime': '13:10', 'trainingFee': 74.0, 'gst': 9, 'gstFee': 6.66, 'baseFee': 80.66, 'totalFee': 80.66, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'OuXLjBYAjPcrOkMAxxb+IjJW9fBetgik/dHzSITUyjs=', 'computedSlotAvl': 1, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2229271, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrSessionNo': 3, 'c3PsrSlotAssign': 3, 'c3PsrSlotAvl': 1, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'N', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 2, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 123, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 66.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 74.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Training Date', 'c3tEffectiveDate': '2024-07-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-31T15:49:58.350+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}, {'slotId': 2229293, 'slotIdEnc': 'Qv/W+Ef6zffkJnFouBA+KQDx/6oooywetEA/W1EvSuk=', 'slotRefName': 'SESSION 5', 'slotRefDate': '2024-08-01 00:00:00', 'startTime': '15:20', 'endTime': '17:00', 'trainingFee': 74.0, 'gst': 9, 'gstFee': 6.66, 'baseFee': 80.66, 'totalFee': 80.66, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'xwofEEeFLfDRqcKWt4pLv7F8CdKiZK1rSiwv7pfRQRk=', 'computedSlotAvl': 1, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2229293, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrSessionNo': 5, 'c3PsrSlotAssign': 3, 'c3PsrSlotAvl': 1, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'N', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 2, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 123, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 66.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 74.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Training Date', 'c3tEffectiveDate': '2024-07-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-31T15:49:58.350+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}, {'slotId': 2229964, 'slotIdEnc': 'QyxZjRWrJBpdXx8jvRrfyrL8b40UHpYZlUn5bTY0JKg=', 'slotRefName': 'SESSION 6', 'slotRefDate': '2024-08-01 00:00:00', 'startTime': '17:10', 'endTime': '18:50', 'trainingFee': 66.0, 'gst': 9, 'gstFee': 5.94, 'baseFee': 71.94, 'totalFee': 71.94, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'koWrCbXWpP56iHQ2/sW1VHLh4mxYracP8LMcZiwfyFU=', 'computedSlotAvl': 4, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2229964, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrSessionNo': 6, 'c3PsrSlotAssign': 5, 'c3PsrSlotAvl': 4, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'D', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 2, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 123, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 66.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 74.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Training Date', 'c3tEffectiveDate': '2024-07-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-31T15:49:58.350+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}, {'slotId': 2229975, 'slotIdEnc': 'mNr7KBNPhlNaG9QYyf1O6KuzCMi73AjmuHfxTuGa5Ao=', 'slotRefName': 'SESSION 7', 'slotRefDate': '2024-08-01 00:00:00', 'startTime': '19:20', 'endTime': '21:00', 'trainingFee': 74.0, 'gst': 9, 'gstFee': 6.66, 'baseFee': 80.66, 'totalFee': 80.66, 'warmUpWithGstFee': None, 'rentalWithGstFee': None, 'commWithGstFee': None, 'fixedInstructorSurcharge': 0, 'venueId': 1, 'slotAvlComputed': True, 'bookingProgress': 'Available', 'bookingProgressEnc': 'pQZVh0lWI7VopUssJJayDJnCJYKtv9pSQgmwi3fK9B8=', 'computedSlotAvl': 1, 'success': False, 'message': None, 'startDateTime': None, 'c3PsrSlotId': 2229975, 'c3PsrFixGrpNo': 'G6067', 'c3PsrTrainingDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrSessionNo': 7, 'c3PsrSlotAssign': 3, 'c3PsrSlotAvl': 1, 'c3PsrTrysell': 0, 'c3PsrCutOffDate': '2024-07-31T16:00:00.000+00:00', 'c3PsrStartTime': None, 'c3PsrEndTime': None, 'c3PsrPriceType': 'N', 'c3PsrSlotRRAss': 0, 'c3PsrSlotRRAvl': 0, 'c3PsrTakeBackAss': 6, 'c3PsrTakeBackRR': 0, 'c3PsrSlotIndicator': 'Class 3', 'c3PsrUserId': None, 'c3PsrTimeStamp': None, 'c3PsrVenueId': None, 'venueName': 'BBDC', 'c3TrainingFeeDtlDTO': {'c3tId': 123, 'c3tType': 'Class 3', 'c3tPriceType': 'NORMAL', 'c3tDayTrainingFee': 66.0, 'c3tDayGst': 9, 'c3tNightTrainingFee': 74.0, 'c3tNightGst': 9, 'c3tDateOpt': 'Training Date', 'c3tEffectiveDate': '2024-07-31T16:00:00.000+00:00', 'c3tUserId': '1152', 'c3tTimeStamp': '2023-12-31T15:49:58.350+00:00'}, 'fixedInstructorFeeDtlDTO': None, 'slotSurcharge': 0.0, 'venueSurcharge': 0.0, 'pickupPointSurcharge': 0.0, 'c3SlotType': None, 'fgCarmodel': None, 'fgTransType': None, 'otherGroupNo': None, 'otherCarModel': None, 'userFixGrpNo': 'G6067', 'userCarModel': 'C', 'userPickupPoint': None}]}


# take out all the keys ,values['startTime,'endTime']

for key, value in data.items():
    # print(key, value)
    for i in value:
        date = i['slotRefDate']
        start_time = i['startTime']
        end_time = i['endTime']
        total_fee = i['totalFee']

        # convert date to a proper date format
        date = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')

        # if is march , april , may or june , print the date
        if date.month in [3, 4, 5, 6]:
            print("YES DATE IS IN MARCH, APRIL, MAY, JUNE")
            print(date, start_time, end_time, total_fee)

        else:
            print('Next Best Date',date ,"Start: ", start_time, "End: ", end_time, "Total Fee: ", total_fee)
            pass
# Out:
# YES DATE IS IN MARCH, APRIL, MAY, JUNE
# 2024-06-16 00:00:00 13:20 15:00 69.76
# Next Best Date 2024-07-18 00:00:00 Start:  09:20 End:  11:00 Total Fee:  78.48
# Next Best Date 2024-07-18 00:00:00 Start:  11:30 End:  13:10 Total Fee:  78.48
# Next Best Date 2024-08-01 00:00:00 Start:  07:30 End:  09:10 Total Fee:  71.94
# Next Best Date 2024-08-01 00:00:00 Start:  09:20 End:  11:00 Total Fee:  80.66
# Next Best Date 2024-08-01 00:00:00 Start:  11:30 End:  13:10 Total Fee:  80.66
# Next Best Date 2024-08-01 00:00:00 Start:  15:20 End:  17:00 Total Fee:  80.66
# Next Best Date 2024-08-01 00:00:00 Start:  17:10 End:  18:50 Total Fee:  71.94
# Next Best Date 2024-08-01 00:00:00 Start:  19:20 End:  21:00 Total Fee:  80.66

# %%
listings = [
          {
            "slotId": 2228809,
            "slotIdEnc": "VuSzhAQGG1eD6pIePdbCgVjKux3SOORvOBbVcFzRaFU=",
            "slotRefName": "SESSION 1",
            "slotRefDate": "2024-08-01 00:00:00",
            "startTime": "07:30",
            "endTime": "09:10",
            "trainingFee": 66,
            "gst": 9,
            "gstFee": 5.94,
            "baseFee": 71.94,
            "totalFee": 71.94,
            "warmUpWithGstFee": null,
            "rentalWithGstFee": null,
            "commWithGstFee": null,
            "fixedInstructorSurcharge": 0,
            "venueId": 1,
            "slotAvlComputed": true,
            "bookingProgress": "Available",
            "bookingProgressEnc": "qGhnPjoXU4Fpfdd1uDeJmLRWQRxK/GHp3zeJQAV7Dfg=",
            "computedSlotAvl": 1,
            "success": false,
            "message": null,
            "startDateTime": null,
            "c3PsrSlotId": 2228809,
            "c3PsrFixGrpNo": "G6067",
            "c3PsrTrainingDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrSessionNo": 1,
            "c3PsrSlotAssign": 3,
            "c3PsrSlotAvl": 1,
            "c3PsrTrysell": 0,
            "c3PsrCutOffDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrStartTime": null,
            "c3PsrEndTime": null,
            "c3PsrPriceType": "D",
            "c3PsrSlotRRAss": 0,
            "c3PsrSlotRRAvl": 0,
            "c3PsrTakeBackAss": 2,
            "c3PsrTakeBackRR": 0,
            "c3PsrSlotIndicator": "Class 3",
            "c3PsrUserId": null,
            "c3PsrTimeStamp": null,
            "c3PsrVenueId": null,
            "venueName": "BBDC",
            "c3TrainingFeeDtlDTO": {
              "c3tId": 123,
              "c3tType": "Class 3",
              "c3tPriceType": "NORMAL",
              "c3tDayTrainingFee": 66,
              "c3tDayGst": 9,
              "c3tNightTrainingFee": 74,
              "c3tNightGst": 9,
              "c3tDateOpt": "Training Date",
              "c3tEffectiveDate": "2024-07-31T16:00:00.000+00:00",
              "c3tUserId": "1152",
              "c3tTimeStamp": "2023-12-31T15:49:58.350+00:00"
            },
            "fixedInstructorFeeDtlDTO": null,
            "slotSurcharge": 0,
            "venueSurcharge": 0,
            "pickupPointSurcharge": 0,
            "c3SlotType": null,
            "fgCarmodel": null,
            "fgTransType": null,
            "otherGroupNo": null,
            "otherCarModel": null,
            "userFixGrpNo": "G6067",
            "userCarModel": "C",
            "userPickupPoint": null
          },
          {
            "slotId": 2228820,
            "slotIdEnc": "/frQOyiBfFulbjBkl5Ajx957us2J3Kq4morUly08u9g=",
            "slotRefName": "SESSION 2",
            "slotRefDate": "2024-08-01 00:00:00",
            "startTime": "09:20",
            "endTime": "11:00",
            "trainingFee": 74,
            "gst": 9,
            "gstFee": 6.66,
            "baseFee": 80.66,
            "totalFee": 80.66,
            "warmUpWithGstFee": null,
            "rentalWithGstFee": null,
            "commWithGstFee": null,
            "fixedInstructorSurcharge": 0,
            "venueId": 1,
            "slotAvlComputed": true,
            "bookingProgress": "Available",
            "bookingProgressEnc": "dWWjoR7O7a9ua4XpDakKEBJ2EM9pNPEA0zATJUSZDpo=",
            "computedSlotAvl": 2,
            "success": false,
            "message": null,
            "startDateTime": null,
            "c3PsrSlotId": 2228820,
            "c3PsrFixGrpNo": "G6067",
            "c3PsrTrainingDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrSessionNo": 2,
            "c3PsrSlotAssign": 3,
            "c3PsrSlotAvl": 2,
            "c3PsrTrysell": 0,
            "c3PsrCutOffDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrStartTime": null,
            "c3PsrEndTime": null,
            "c3PsrPriceType": "N",
            "c3PsrSlotRRAss": 0,
            "c3PsrSlotRRAvl": 0,
            "c3PsrTakeBackAss": 2,
            "c3PsrTakeBackRR": 0,
            "c3PsrSlotIndicator": "Class 3",
            "c3PsrUserId": null,
            "c3PsrTimeStamp": null,
            "c3PsrVenueId": null,
            "venueName": "BBDC",
            "c3TrainingFeeDtlDTO": {
              "c3tId": 123,
              "c3tType": "Class 3",
              "c3tPriceType": "NORMAL",
              "c3tDayTrainingFee": 66,
              "c3tDayGst": 9,
              "c3tNightTrainingFee": 74,
              "c3tNightGst": 9,
              "c3tDateOpt": "Training Date",
              "c3tEffectiveDate": "2024-07-31T16:00:00.000+00:00",
              "c3tUserId": "1152",
              "c3tTimeStamp": "2023-12-31T15:49:58.350+00:00"
            },
            "fixedInstructorFeeDtlDTO": null,
            "slotSurcharge": 0,
            "venueSurcharge": 0,
            "pickupPointSurcharge": 0,
            "c3SlotType": null,
            "fgCarmodel": null,
            "fgTransType": null,
            "otherGroupNo": null,
            "otherCarModel": null,
            "userFixGrpNo": "G6067",
            "userCarModel": "C",
            "userPickupPoint": null
          },
          {
            "slotId": 2229271,
            "slotIdEnc": "pTJldNXIE4T40XoEnb66ZZJeC0x0Ie0d9vLh/0Jnny0=",
            "slotRefName": "SESSION 3",
            "slotRefDate": "2024-08-01 00:00:00",
            "startTime": "11:30",
            "endTime": "13:10",
            "trainingFee": 74,
            "gst": 9,
            "gstFee": 6.66,
            "baseFee": 80.66,
            "totalFee": 80.66,
            "warmUpWithGstFee": null,
            "rentalWithGstFee": null,
            "commWithGstFee": null,
            "fixedInstructorSurcharge": 0,
            "venueId": 1,
            "slotAvlComputed": true,
            "bookingProgress": "Available",
            "bookingProgressEnc": "OuXLjBYAjPcrOkMAxxb+IjJW9fBetgik/dHzSITUyjs=",
            "computedSlotAvl": 1,
            "success": false,
            "message": null,
            "startDateTime": null,
            "c3PsrSlotId": 2229271,
            "c3PsrFixGrpNo": "G6067",
            "c3PsrTrainingDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrSessionNo": 3,
            "c3PsrSlotAssign": 3,
            "c3PsrSlotAvl": 1,
            "c3PsrTrysell": 0,
            "c3PsrCutOffDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrStartTime": null,
            "c3PsrEndTime": null,
            "c3PsrPriceType": "N",
            "c3PsrSlotRRAss": 0,
            "c3PsrSlotRRAvl": 0,
            "c3PsrTakeBackAss": 2,
            "c3PsrTakeBackRR": 0,
            "c3PsrSlotIndicator": "Class 3",
            "c3PsrUserId": null,
            "c3PsrTimeStamp": null,
            "c3PsrVenueId": null,
            "venueName": "BBDC",
            "c3TrainingFeeDtlDTO": {
              "c3tId": 123,
              "c3tType": "Class 3",
              "c3tPriceType": "NORMAL",
              "c3tDayTrainingFee": 66,
              "c3tDayGst": 9,
              "c3tNightTrainingFee": 74,
              "c3tNightGst": 9,
              "c3tDateOpt": "Training Date",
              "c3tEffectiveDate": "2024-07-31T16:00:00.000+00:00",
              "c3tUserId": "1152",
              "c3tTimeStamp": "2023-12-31T15:49:58.350+00:00"
            },
            "fixedInstructorFeeDtlDTO": null,
            "slotSurcharge": 0,
            "venueSurcharge": 0,
            "pickupPointSurcharge": 0,
            "c3SlotType": null,
            "fgCarmodel": null,
            "fgTransType": null,
            "otherGroupNo": null,
            "otherCarModel": null,
            "userFixGrpNo": "G6067",
            "userCarModel": "C",
            "userPickupPoint": null
          },
          {
            "slotId": 2229293,
            "slotIdEnc": "Qv/W+Ef6zffkJnFouBA+KXAvzhT0+oUATZViqlQr1aU=",
            "slotRefName": "SESSION 5",
            "slotRefDate": "2024-08-01 00:00:00",
            "startTime": "15:20",
            "endTime": "17:00",
            "trainingFee": 74,
            "gst": 9,
            "gstFee": 6.66,
            "baseFee": 80.66,
            "totalFee": 80.66,
            "warmUpWithGstFee": null,
            "rentalWithGstFee": null,
            "commWithGstFee": null,
            "fixedInstructorSurcharge": 0,
            "venueId": 1,
            "slotAvlComputed": true,
            "bookingProgress": "Available",
            "bookingProgressEnc": "xwofEEeFLfDRqcKWt4pLv7F8CdKiZK1rSiwv7pfRQRk=",
            "computedSlotAvl": 1,
            "success": false,
            "message": null,
            "startDateTime": null,
            "c3PsrSlotId": 2229293,
            "c3PsrFixGrpNo": "G6067",
            "c3PsrTrainingDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrSessionNo": 5,
            "c3PsrSlotAssign": 3,
            "c3PsrSlotAvl": 1,
            "c3PsrTrysell": 0,
            "c3PsrCutOffDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrStartTime": null,
            "c3PsrEndTime": null,
            "c3PsrPriceType": "N",
            "c3PsrSlotRRAss": 0,
            "c3PsrSlotRRAvl": 0,
            "c3PsrTakeBackAss": 2,
            "c3PsrTakeBackRR": 0,
            "c3PsrSlotIndicator": "Class 3",
            "c3PsrUserId": null,
            "c3PsrTimeStamp": null,
            "c3PsrVenueId": null,
            "venueName": "BBDC",
            "c3TrainingFeeDtlDTO": {
              "c3tId": 123,
              "c3tType": "Class 3",
              "c3tPriceType": "NORMAL",
              "c3tDayTrainingFee": 66,
              "c3tDayGst": 9,
              "c3tNightTrainingFee": 74,
              "c3tNightGst": 9,
              "c3tDateOpt": "Training Date",
              "c3tEffectiveDate": "2024-07-31T16:00:00.000+00:00",
              "c3tUserId": "1152",
              "c3tTimeStamp": "2023-12-31T15:49:58.350+00:00"
            },
            "fixedInstructorFeeDtlDTO": null,
            "slotSurcharge": 0,
            "venueSurcharge": 0,
            "pickupPointSurcharge": 0,
            "c3SlotType": null,
            "fgCarmodel": null,
            "fgTransType": null,
            "otherGroupNo": null,
            "otherCarModel": null,
            "userFixGrpNo": "G6067",
            "userCarModel": "C",
            "userPickupPoint": null
          },
          {
            "slotId": 2229964,
            "slotIdEnc": "QyxZjRWrJBpdXx8jvRrfys8EUxff/54q7bim2Qdbu/o=",
            "slotRefName": "SESSION 6",
            "slotRefDate": "2024-08-01 00:00:00",
            "startTime": "17:10",
            "endTime": "18:50",
            "trainingFee": 66,
            "gst": 9,
            "gstFee": 5.94,
            "baseFee": 71.94,
            "totalFee": 71.94,
            "warmUpWithGstFee": null,
            "rentalWithGstFee": null,
            "commWithGstFee": null,
            "fixedInstructorSurcharge": 0,
            "venueId": 1,
            "slotAvlComputed": true,
            "bookingProgress": "Available",
            "bookingProgressEnc": "koWrCbXWpP56iHQ2/sW1VHLh4mxYracP8LMcZiwfyFU=",
            "computedSlotAvl": 4,
            "success": false,
            "message": null,
            "startDateTime": null,
            "c3PsrSlotId": 2229964,
            "c3PsrFixGrpNo": "G6067",
            "c3PsrTrainingDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrSessionNo": 6,
            "c3PsrSlotAssign": 5,
            "c3PsrSlotAvl": 4,
            "c3PsrTrysell": 0,
            "c3PsrCutOffDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrStartTime": null,
            "c3PsrEndTime": null,
            "c3PsrPriceType": "D",
            "c3PsrSlotRRAss": 0,
            "c3PsrSlotRRAvl": 0,
            "c3PsrTakeBackAss": 2,
            "c3PsrTakeBackRR": 0,
            "c3PsrSlotIndicator": "Class 3",
            "c3PsrUserId": null,
            "c3PsrTimeStamp": null,
            "c3PsrVenueId": null,
            "venueName": "BBDC",
            "c3TrainingFeeDtlDTO": {
              "c3tId": 123,
              "c3tType": "Class 3",
              "c3tPriceType": "NORMAL",
              "c3tDayTrainingFee": 66,
              "c3tDayGst": 9,
              "c3tNightTrainingFee": 74,
              "c3tNightGst": 9,
              "c3tDateOpt": "Training Date",
              "c3tEffectiveDate": "2024-07-31T16:00:00.000+00:00",
              "c3tUserId": "1152",
              "c3tTimeStamp": "2023-12-31T15:49:58.350+00:00"
            },
            "fixedInstructorFeeDtlDTO": null,
            "slotSurcharge": 0,
            "venueSurcharge": 0,
            "pickupPointSurcharge": 0,
            "c3SlotType": null,
            "fgCarmodel": null,
            "fgTransType": null,
            "otherGroupNo": null,
            "otherCarModel": null,
            "userFixGrpNo": "G6067",
            "userCarModel": "C",
            "userPickupPoint": null
          },
          {
            "slotId": 2229975,
            "slotIdEnc": "mNr7KBNPhlNaG9QYyf1O6A1qe90U3uOYfAH9jYEeSLg=",
            "slotRefName": "SESSION 7",
            "slotRefDate": "2024-08-01 00:00:00",
            "startTime": "19:20",
            "endTime": "21:00",
            "trainingFee": 74,
            "gst": 9,
            "gstFee": 6.66,
            "baseFee": 80.66,
            "totalFee": 80.66,
            "warmUpWithGstFee": null,
            "rentalWithGstFee": null,
            "commWithGstFee": null,
            "fixedInstructorSurcharge": 0,
            "venueId": 1,
            "slotAvlComputed": true,
            "bookingProgress": "Available",
            "bookingProgressEnc": "pQZVh0lWI7VopUssJJayDJnCJYKtv9pSQgmwi3fK9B8=",
            "computedSlotAvl": 1,
            "success": false,
            "message": null,
            "startDateTime": null,
            "c3PsrSlotId": 2229975,
            "c3PsrFixGrpNo": "G6067",
            "c3PsrTrainingDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrSessionNo": 7,
            "c3PsrSlotAssign": 3,
            "c3PsrSlotAvl": 1,
            "c3PsrTrysell": 0,
            "c3PsrCutOffDate": "2024-07-31T16:00:00.000+00:00",
            "c3PsrStartTime": null,
            "c3PsrEndTime": null,
            "c3PsrPriceType": "N",
            "c3PsrSlotRRAss": 0,
            "c3PsrSlotRRAvl": 0,
            "c3PsrTakeBackAss": 6,
            "c3PsrTakeBackRR": 0,
            "c3PsrSlotIndicator": "Class 3",
            "c3PsrUserId": null,
            "c3PsrTimeStamp": null,
            "c3PsrVenueId": null,
            "venueName": "BBDC",
            "c3TrainingFeeDtlDTO": {
              "c3tId": 123,
              "c3tType": "Class 3",
              "c3tPriceType": "NORMAL",
              "c3tDayTrainingFee": 66,
              "c3tDayGst": 9,
              "c3tNightTrainingFee": 74,
              "c3tNightGst": 9,
              "c3tDateOpt": "Training Date",
              "c3tEffectiveDate": "2024-07-31T16:00:00.000+00:00",
              "c3tUserId": "1152",
              "c3tTimeStamp": "2023-12-31T15:49:58.350+00:00"
            },
            "fixedInstructorFeeDtlDTO": null,
            "slotSurcharge": 0,
            "venueSurcharge": 0,
            "pickupPointSurcharge": 0,
            "c3SlotType": null,
            "fgCarmodel": null,
            "fgTransType": null,
            "otherGroupNo": null,
            "otherCarModel": null,
            "userFixGrpNo": "G6067",
            "userCarModel": "C",
            "userPickupPoint": null
          }
        ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 14
#       1 listings = [
#       2           {
#       3             "slotId": 2228809,
#       4             "slotIdEnc": "VuSzhAQGG1eD6pIePdbCgVjKux3SOORvOBbVcFzRaFU=",
#       5             "slotRefName": "SESSION 1",
#       6             "slotRefDate": "2024-08-01 00:00:00",
#       7             "startTime": "07:30",
#       8             "endTime": "09:10",
#       9             "trainingFee": 66,
#      10             "gst": 9,
#      11             "gstFee": 5.94,
#      12             "baseFee": 71.94,
#      13             "totalFee": 71.94,
# ---> 14             "warmUpWithGstFee": null,
#      15             "rentalWithGstFee": null,
#      16             "commWithGstFee": null,
#      17             "fixedInstructorSurcharge": 0,
#      18             "venueId": 1,
# ...
